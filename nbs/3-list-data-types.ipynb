# %%
import requests
from pprint import pprint
path = "/api/events"
base_url = "http://localhost:8002" # 127.0.0.1
endpoint = f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8002/api/events'

# %%
response = requests.get(endpoint, params={'duration': '15 minutes', 'pages': []})
print('ok', response.ok)
if response.ok:
    data = response.json()
    pprint(data)
# Out:
# ok True
# [{'avg_duration': 149.3,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 90,
#   'operating_system': 'Android',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 145.25,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 88,
#   'operating_system': 'Android',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 165.92233009708738,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 103,
#   'operating_system': 'Android',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 141.51685393258427,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 89,
#   'operating_system': 'Android',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 137.2135922330097,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 103,
#   'operating_system': 'Android',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 164.1184210526316,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 76,
#   'operating_system': 'Android',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 165.24096385542168,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 83,
#   'operating_system': 'Android',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 144.68367346938774,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 98,
#   'operating_system': 'Android',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 150.9764705882353,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 85,
#   'operating_system': 'Android',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 152.56521739130434,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 92,
#   'operating_system': 'Android',
#   'page': '/signup',
#   'ua': ''},
#  {'avg_duration': 146.49528301886792,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 212,
#   'operating_system': 'Linux',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 153.64150943396226,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 212,
#   'operating_system': 'Linux',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 146.32857142857142,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 210,
#   'operating_system': 'Linux',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 151.96638655462183,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 238,
#   'operating_system': 'Linux',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 151.8640776699029,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 206,
#   'operating_system': 'Linux',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 145.40196078431373,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 204,
#   'operating_system': 'Linux',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 144.31034482758622,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 232,
#   'operating_system': 'Linux',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 157.65258215962442,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 213,
#   'operating_system': 'Linux',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 148.1798245614035,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 228,
#   'operating_system': 'Linux',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 147.906103286385,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 213,
#   'operating_system': 'Linux',
#   'page': '/signup',
#   'ua': ''},
#  {'avg_duration': 145.53591160220995,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 181,
#   'operating_system': 'MacOS',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 147.02083333333334,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 192,
#   'operating_system': 'MacOS',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 148.4060606060606,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 165,
#   'operating_system': 'MacOS',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 150.76785714285714,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 168,
#   'operating_system': 'MacOS',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 163.1604938271605,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 162,
#   'operating_system': 'MacOS',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 156.05357142857142,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 168,
#   'operating_system': 'MacOS',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 157.51381215469613,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 181,
#   'operating_system': 'MacOS',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 152.73295454545453,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 176,
#   'operating_system': 'MacOS',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 154.82065217391303,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 184,
#   'operating_system': 'MacOS',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 154.96666666666667,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 180,
#   'operating_system': 'MacOS',
#   'page': '/signup',
#   'ua': ''},
#  {'avg_duration': 154.02272727272728,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 44,
#   'operating_system': 'Other',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 164.68627450980392,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 51,
#   'operating_system': 'Other',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 151.65714285714284,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 35,
#   'operating_system': 'Other',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 141.703125,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 64,
#   'operating_system': 'Other',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 157.54166666666666,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 48,
#   'operating_system': 'Other',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 147.78181818181818,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 55,
#   'operating_system': 'Other',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 130.0,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 58,
#   'operating_system': 'Other',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 135.70833333333334,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 48,
#   'operating_system': 'Other',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 165.7674418604651,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 43,
#   'operating_system': 'Other',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 141.23076923076923,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 52,
#   'operating_system': 'Other',
#   'page': '/signup',
#   'ua': ''},
#  {'avg_duration': 153.30746268656716,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 335,
#   'operating_system': 'Windows',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 154.53602305475505,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 347,
#   'operating_system': 'Windows',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 155.91076923076923,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 325,
#   'operating_system': 'Windows',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 160.18562874251498,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 334,
#   'operating_system': 'Windows',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 144.15068493150685,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 365,
#   'operating_system': 'Windows',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 153.8583569405099,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 353,
#   'operating_system': 'Windows',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 146.85131195335276,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 343,
#   'operating_system': 'Windows',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 149.1021021021021,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 333,
#   'operating_system': 'Windows',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 153.3562874251497,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 334,
#   'operating_system': 'Windows',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 152.54455445544554,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 303,
#   'operating_system': 'Windows',
#   'page': '/signup',
#   'ua': ''},
#  {'avg_duration': 139.21167883211677,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 137,
#   'operating_system': 'iOS',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 146.28455284552845,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 123,
#   'operating_system': 'iOS',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 162.6694214876033,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 121,
#   'operating_system': 'iOS',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 152.1590909090909,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 132,
#   'operating_system': 'iOS',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 150.4296875,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 128,
#   'operating_system': 'iOS',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 165.03305785123968,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 121,
#   'operating_system': 'iOS',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 158.35658914728683,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 129,
#   'operating_system': 'iOS',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 149.58219178082192,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 146,
#   'operating_system': 'iOS',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 157.62043795620437,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 137,
#   'operating_system': 'iOS',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 137.57258064516128,
#   'bucket': '2025-03-21T20:30:00Z',
#   'count': 124,
#   'operating_system': 'iOS',
#   'page': '/signup',
#   'ua': ''},
#  {'avg_duration': 2568.0,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 42,
#   'operating_system': 'Android',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 2125.4473684210525,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 38,
#   'operating_system': 'Android',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 2710.057142857143,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 35,
#   'operating_system': 'Android',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 2321.764705882353,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 34,
#   'operating_system': 'Android',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 2294.6170212765956,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 47,
#   'operating_system': 'Android',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 2862.6071428571427,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 28,
#   'operating_system': 'Android',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 2309.4324324324325,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 37,
#   'operating_system': 'Android',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 2553.2285714285713,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 35,
#   'operating_system': 'Android',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 2301.375,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 32,
#   'operating_system': 'Android',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 2828.342105263158,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 38,
#   'operating_system': 'Android',
#   'page': '/signup',
#   'ua': ''},
#  {'avg_duration': 2324.042857142857,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 70,
#   'operating_system': 'Linux',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 2240.896551724138,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 87,
#   'operating_system': 'Linux',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 2199.6582278481014,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 79,
#   'operating_system': 'Linux',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 2606.779411764706,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 68,
#   'operating_system': 'Linux',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 2455.190476190476,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 84,
#   'operating_system': 'Linux',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 2555.3263157894735,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 95,
#   'operating_system': 'Linux',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 2678.098901098901,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 91,
#   'operating_system': 'Linux',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 2255.6494845360826,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 97,
#   'operating_system': 'Linux',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 2808.358024691358,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 81,
#   'operating_system': 'Linux',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 2684.94623655914,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 93,
#   'operating_system': 'Linux',
#   'page': '/signup',
#   'ua': ''},
#  {'avg_duration': 2600.9384615384615,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 65,
#   'operating_system': 'MacOS',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 2637.203703703704,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 54,
#   'operating_system': 'MacOS',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 2662.3508771929824,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 57,
#   'operating_system': 'MacOS',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 2787.5692307692307,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 65,
#   'operating_system': 'MacOS',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 2408.690909090909,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 55,
#   'operating_system': 'MacOS',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 2379.186440677966,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 59,
#   'operating_system': 'MacOS',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 2602.768115942029,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 69,
#   'operating_system': 'MacOS',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 2644.530303030303,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 66,
#   'operating_system': 'MacOS',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 2519.740740740741,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 54,
#   'operating_system': 'MacOS',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 2339.9857142857145,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 70,
#   'operating_system': 'MacOS',
#   'page': '/signup',
#   'ua': ''},
#  {'avg_duration': 2757.0,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 22,
#   'operating_system': 'Other',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 2691.75,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 16,
#   'operating_system': 'Other',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 2837.153846153846,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 13,
#   'operating_system': 'Other',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 2409.230769230769,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 13,
#   'operating_system': 'Other',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 2547.96,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 25,
#   'operating_system': 'Other',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 1896.7333333333333,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 15,
#   'operating_system': 'Other',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 2372.4444444444443,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 18,
#   'operating_system': 'Other',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 2339.15,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 20,
#   'operating_system': 'Other',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 2680.3333333333335,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 30,
#   'operating_system': 'Other',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 2581.5454545454545,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 11,
#   'operating_system': 'Other',
#   'page': '/signup',
#   'ua': ''},
#  {'avg_duration': 2638.0289855072465,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 138,
#   'operating_system': 'Windows',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 2619.788732394366,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 142,
#   'operating_system': 'Windows',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 2525.7433628318586,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 113,
#   'operating_system': 'Windows',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 2226.844827586207,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 116,
#   'operating_system': 'Windows',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 2660.301369863014,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 146,
#   'operating_system': 'Windows',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 2329.0,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 121,
#   'operating_system': 'Windows',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 2483.771653543307,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 127,
#   'operating_system': 'Windows',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 2491.939393939394,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 132,
#   'operating_system': 'Windows',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 2669.9055118110236,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 127,
#   'operating_system': 'Windows',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 2453.9139072847684,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 151,
#   'operating_system': 'Windows',
#   'page': '/signup',
#   'ua': ''},
#  {'avg_duration': 2440.34,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 50,
#   'operating_system': 'iOS',
#   'page': '/',
#   'ua': ''},
#  {'avg_duration': 2492.068181818182,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 44,
#   'operating_system': 'iOS',
#   'page': '/about',
#   'ua': ''},
#  {'avg_duration': 2202.8260869565215,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 46,
#   'operating_system': 'iOS',
#   'page': '/blog',
#   'ua': ''},
#  {'avg_duration': 2293.2444444444445,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 45,
#   'operating_system': 'iOS',
#   'page': '/contact',
#   'ua': ''},
#  {'avg_duration': 2320.114285714286,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 35,
#   'operating_system': 'iOS',
#   'page': '/dashboard',
#   'ua': ''},
#  {'avg_duration': 2339.7727272727275,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 44,
#   'operating_system': 'iOS',
#   'page': '/login',
#   'ua': ''},
#  {'avg_duration': 2864.5,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 44,
#   'operating_system': 'iOS',
#   'page': '/pricing',
#   'ua': ''},
#  {'avg_duration': 2763.064516129032,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 62,
#   'operating_system': 'iOS',
#   'page': '/products',
#   'ua': ''},
#  {'avg_duration': 2777.684210526316,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 38,
#   'operating_system': 'iOS',
#   'page': '/settings',
#   'ua': ''},
#  {'avg_duration': 2553.9454545454546,
#   'bucket': '2025-03-21T20:45:00Z',
#   'count': 55,
#   'operating_system': 'iOS',
#   'page': '/signup',
#   'ua': ''}]

# %%
detail_path = "/api/events/12"
detail_endpoint = f"{base_url}{detail_path}"
r = requests.get(detail_endpoint)
print('ok', r.status_code)
if r.ok:
    data = r.json()
    pprint(data)
# Out:
# ok 404
