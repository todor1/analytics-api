# %%
import requests
from pprint import pprint
path = "/api/events"
base_url = "http://localhost:8002" # 127.0.0.1
endpoint = f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8002/api/events'

# %%
response = requests.get(endpoint, params={'duration': '1 week', 'pages': []})
print('ok', response.ok)
if response.ok:
    data = response.json()
    pprint(data)
# Out:
# ok True
# [{'bucket': '2025-03-17T00:00:00Z', 'count': 938, 'page': '/about'},
#  {'bucket': '2025-03-17T00:00:00Z', 'count': 1042, 'page': '/contact'},
#  {'bucket': '2025-03-17T00:00:00Z', 'count': 1005, 'page': '/pricing'}]

# %%
detail_path = "/api/events/12"
detail_endpoint = f"{base_url}{detail_path}"
r = requests.get(detail_endpoint)
print('ok', r.status_code)
if r.ok:
    data = r.json()
    pprint(data)
# Out:
# ok 404
